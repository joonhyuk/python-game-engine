# %%
from lib.foundation import *
from matplotlib import pyplot as plt
# Out:
# lib-/home/mash/Projects/PyArcadeTest/lib/__init__.py
# include lib.foundation.vector : /home/mash/Projects/PyArcadeTest/lib/foundation/vector.py
# include lib.foundation.base : /home/mash/Projects/PyArcadeTest/lib/foundation/base.py
# include lib.foundation.clock : /home/mash/Projects/PyArcadeTest/lib/foundation/clock.py
# CLOCK initialized
# include lib.foundation.engine.app : /home/mash/Projects/PyArcadeTest/lib/foundation/engine/app.py
# GAME initialized
# include lib.foundation.world : /home/mash/Projects/PyArcadeTest/lib/foundation/world.py

# %%
pos = Vector(100,100)
area = Vector(100,100)

plts = []
for _ in range(1000):
    plts.append(get_random_pos(pos, 00, area, area_shape='elipse'))

xs, ys = zip(*plts)
plt.scatter(xs, ys)
